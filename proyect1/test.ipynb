# %%
import numpy as np
import pandas as pd

# %%
date_to_run = '201306'
filepath = '/Users/usuario/Library/CloudStorage/OneDrive-Personal/Loka/repositories/data-eng-course/lake/raw_files/201306-citibike-tripdata.csv'

# %%
#col_names=['tripduration','starttime','stoptime','start_station_id','end_station_id', 'bikeid']
#df = pd.read_csv(filepath, names=col_names, low_memory=False)
df = pd.read_csv(filepath)
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
df['starttime'] = pd.to_datetime(df['starttime'],format='%Y/%m/%d %H:%M:%S')
df['stoptime'] = pd.to_datetime(df['stoptime'],format='%Y/%m/%d %H:%M:%S')
df
# Out:
#         tripduration           starttime            stoptime  \
# 0                695 2013-06-01 00:00:01 2013-06-01 00:11:36
# 1                693 2013-06-01 00:00:08 2013-06-01 00:11:41
# 2               2059 2013-06-01 00:00:44 2013-06-01 00:35:03
# 3                123 2013-06-01 00:01:04 2013-06-01 00:03:07
# 4               1521 2013-06-01 00:01:22 2013-06-01 00:26:43
# ...              ...                 ...                 ...
# 577698           925 2013-06-30 23:59:27 2013-07-01 00:14:52
# 577699           279 2013-06-30 23:59:36 2013-07-01 00:04:15
# 577700           161 2013-06-30 23:59:33 2013-07-01 00:02:14
# 577701           909 2013-06-30 23:59:47 2013-07-01 00:14:56
# 577702           634 2013-07-01 00:00:00 2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# 1                    444      Broadway & W 24 St               40.742354
# ...

# %%
#Delete rows with null values
def drop_missing(df):
    df.dropna(subset=['tripduration','starttime','stoptime','start station id','end station id', 'bikeid'], inplace=True)
    return df

# %%
#remove rows without sense 
def remove_outliers_dates(df, column_date_start, column_date_end):
    df[column_date_start] = pd.to_datetime(df[column_date_start],format='%Y/%m/%d %H:%M:%S')
    df[column_date_end] = pd.to_datetime(df[column_date_end],format='%Y/%m/%d %H:%M:%S')
    #get index of rows where starttime > stoptime
    index_del = df[df[column_date_start] > df[column_date_end]].index
    # drop these given row
    # indexes from dataFrame
    df.drop(index_del, inplace = True)
    df['start_date']= df[column_date_start].dt.date
    return df

# %%
def copy_df(df):
   return df.copy()

# %%
def convert_int_values(df, column_names):
    for column_name in column_names:
        df[column_name] = df[column_name].fillna(0)
        df[column_name]= df[column_name].astype(int)
    return df

# %%
df_cleaned = ( df.
                pipe(copy_df).
                pipe(drop_missing).
                pipe(remove_outliers_dates, 'starttime', 'stoptime').
                pipe(convert_int_values, ['start station id', 'end station id','birth year', 'gender'])
                
            )

# %%
df_cleaned
# Out:
#         tripduration           starttime            stoptime  \
# 0                695 2013-06-01 00:00:01 2013-06-01 00:11:36
# 1                693 2013-06-01 00:00:08 2013-06-01 00:11:41
# 2               2059 2013-06-01 00:00:44 2013-06-01 00:35:03
# 3                123 2013-06-01 00:01:04 2013-06-01 00:03:07
# 4               1521 2013-06-01 00:01:22 2013-06-01 00:26:43
# ...              ...                 ...                 ...
# 577698           925 2013-06-30 23:59:27 2013-07-01 00:14:52
# 577699           279 2013-06-30 23:59:36 2013-07-01 00:04:15
# 577700           161 2013-06-30 23:59:33 2013-07-01 00:02:14
# 577701           909 2013-06-30 23:59:47 2013-07-01 00:14:56
# 577702           634 2013-07-01 00:00:00 2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# 1                    444      Broadway & W 24 St               40.742354
# ...

# %%
df.shape
# Out:
# (577703, 15)

# %%
df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                        float64
# gender                              int64
# dtype: object

# %%
df_cleaned.shape
# Out:
# (559644, 15)

# %%
import fnmatch
import os

path = '/Users/usuario/Library/CloudStorage/OneDrive-Personal/Loka/repositories/data-eng-course/lake/pending_files'
#print(os.listdir('/Users/usuario/Library/CloudStorage/OneDrive-Personal/Loka/repositories/data-eng-course/lake/pending_files'))
date = '201306'
for file in os.listdir(path):
    print(file.find(date))
    if fnmatch.fnmatchcase(file, '201306'):
        print('....')
        print(file)
# Out:
# -1
# 0

# %%
CONN_DB_DIC = {
    "host"      : "localhost",
   # "database"  : DB_NAME,
    "user"      : "postgres",
    "password"  : "postgres"
}

# %%
print(CONN_DB_DIC)
# Out:
# {'host': 'localhost', 'user': 'postgres', 'password': 'postgres'}

# %%
DB_NAME                     = 'trip'
conn_params_dic = CONN_DB_DIC
conn_params_dic['database'] = DB_NAME
print(conn_params_dic)
# Out:
# {'host': 'localhost', 'user': 'postgres', 'password': 'postgres', 'database': 'trip'}

# %%
df_cleaned.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                        float64
# gender                              int64
# dtype: object
